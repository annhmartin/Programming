# %%
# Connect Four game board creation, 6 rows, 7 columns

Player1 = input("Name for Player 1")
Player2 = input("Name for Player 2")

while Player2 == Player1:
    Player2 = input("Oops, pick a different name for Player 2")

print(f"\nWelcome {Player1} and {Player2}!\n")

Player1Character = input(f"{Player1} what character do you want to represent your moves?") 
Player2Character = input(f"{Player2} what character do you want to represent your moves?") 

while Player2Character == Player1Character:
    Player2Character = input("Oops, pick a different character for Player 2")

print(f"Let`s get started, here is the game board!\n")

Row1 = [" "," "," "," "," "," "," "] 
Row2 = [" "," "," "," "," "," "," "] 
Row3 = [" "," "," "," "," "," "," "] 
Row4 = [" "," "," "," "," "," "," "] 
Row5 = [" "," "," "," "," "," "," "] 
Row6 = [" "," "," "," "," "," "," "] 

print(Row1)
print(Row2)
print(Row3)
print(Row4)
print(Row5)
print(Row6)

print("\nHere are the column numbers.")
ColumnNames = [0,1,2,3,4,5,6]
print(f"{ColumnNames}")
# Out:
# Name for Player 1 Elizabeth
# Name for Player 2 Danielle
# Welcome Elizabeth and Danielle!
# Elizabeth what character do you want to represent your moves? %
# Danielle what character do you want to represent your moves? &
# Let`s get started, here is the game board!
#
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
#
# Here are the column numbers.
# [0, 1, 2, 3, 4, 5, 6]

# %%
print(Row1)
print(Row2)
print(Row3)
print(Row4)
print(Row5)
print(Row6)

print("\nHere are the column numbers.")
ColumnNames = [0,1,2,3,4,5,6]
print(f"{ColumnNames}")

print(f"{Player1} your turn.")
Play1 = int(input(f"Which column do you want to drop your {Player1Character} into?"))


if Row6[Play1] == " ":
    Row6[Play1] = Player1Character
elif Row5[Play1] == " ":
    Row5[Play1] = Player1Character
elif Row4[Play1] == " ":
    Row4[Play1] = Player1Character
elif Row3[Play1] == " ":
    Row3[Play1] = Player1Character
elif Row2[Play1] == " ":
    Row2[Play1] = Player1Character
elif Row1[Play1] == " ":
    Row1[Play1] = Player1Character
else:Play1 = int(input(f"Oop, that is not a valid move.\nWhich column do you want to drop your {Player1Character} into?"))

print(Row1)
print(Row2)
print(Row3)
print(Row4)
print(Row5)
print(Row6)

print(f"\n{Player2} your turn.")
Play2 = int(input(f"Which column do you want to drop your {Player2Character} into?"))

if Row6[Play2] == " ":
    Row6[Play2] = Player2Character
elif Row5[Play2] == " ":
    Row5[Play2] = Player2Character
elif Row4[Play2] == " ":
    Row4[Play2] = Player2Character
elif Row3[Play2] == " ":
    Row3[Play2] = Player2Character
elif Row2[Play2] == " ":
    Row2[Play2] = Player2Character
elif Row1[Play2] == " ":
    Row1[Play2] = Player2Character
else: Play2 = int(input(f"Oop, that is not a valid move.\nWhich column do you want to drop your {Player2Character} into?"))

print(Row1)
print(Row2)
print(Row3)
print(Row4)
print(Row5)
print(Row6)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', '&', '%', ' ', ' ', ' ']
# ['&', '&', '&', '%', '%', '%', ' ']
#
# Here are the column numbers.
# [0, 1, 2, 3, 4, 5, 6]
# Elizabeth your turn.
# Which column do you want to drop your % into? 6
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', '&', '%', ' ', ' ', ' ']
# ['&', '&', '&', '%', '%', '%', '%']
#
# Danielle your turn.
# Which column do you want to drop your & into? 2
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', '&', ' ', ' ', ' ', ' ']
# [' ', ' ', '&', '%', ' ', ' ', ' ']
# ['&', '&', '&', '%', '%', '%', '%']
