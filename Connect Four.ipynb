# %%
#importing colors

import sys
# !{sys.executable} -m pip install termcolor

from termcolor import colored

# %%
# Connect Four game board creation, 6 rows, 7 columns

Player1 = input("Name for Player 1")
Player2 = input("Name for Player 2")

while Player2 == Player1:
    Player2 = input("Oops, pick a different name for Player 2")

print(f"\nWelcome {Player1} and {Player2}!\n")


ColorOptions = ["red","green","yellow","blue","magenta"]

print(f"Now you need to choose a color for your pieces.\nHere are the options:")
print(colored("red","red"), colored("green","green"), colored("yellow","yellow"), colored("blue","blue"), colored("magenta","magenta"))

Player1Color = input(f"{Player1} what color do you want to represent you?")
while Player1Color not in ColorOptions:
    Player1Color = input(f"Oops, pick a color from the list {Player1}")

Player2Color = input(f"{Player2} what color do you want to represent you?") 
while Player2Color not in ColorOptions:
    Player2Color = input(f"Oops, pick a color from the list {Player2}")

while Player2Color == Player1Color:
    Player2Color = input(f"Oops, pick a different color for {Player2}")

print(f"Let`s get started!\n")

Row1 = [colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black")]
Row2 = [colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black")]
Row3 = [colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black")]
Row4 = [colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black")]
Row5 = [colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black")]
Row6 = [colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black"),colored("0", "black")]

# %%
print(f"Here is the current game board\n")

print("[" + ", ".join(Row1) + "]")
print("[" + ", ".join(Row2) + "]")
print("[" + ", ".join(Row3) + "]")
print("[" + ", ".join(Row4) + "]")
print("[" + ", ".join(Row5) + "]")
print("[" + ", ".join(Row6) + "]")

print("\nHere are the column numbers")
ColumnNames = [0,1,2,3,4,5,6]
print(f"{ColumnNames}")

print(f"\n{Player1} your turn.")
Play1 = int(input(f"Which column do you want to drop your {Player1Color} piece into?\n"))
#need to handle non numbers and numbers greater than 6

if Row6[Play1] == colored("0", "black"):
    Row6[Play1] = colored("0",f"{Player1Color}")
elif Row5[Play1] == colored("0", "black"):
    Row5[Play1] = colored("0",f"{Player1Color}")
elif Row4[Play1] == colored("0", "black"):
    Row4[Play1] = colored("0",f"{Player1Color}")
elif Row3[Play1] == colored("0", "black"):
    Row3[Play1] = colored("0",f"{Player1Color}")
elif Row2[Play1] == colored("0", "black"):
    Row2[Play1] = colored("0",f"{Player1Color}")
elif Row1[Play1] == colored("0", "black"):
    Row1[Play1] = colored("0",f"{Player1Color}")
else:Play1 = int(input(f"Oop, that is not a valid move.\nWhich column do you want to drop your {Player1Color} piece into?\n"))

print("[" + ", ".join(Row1) + "]")
print("[" + ", ".join(Row2) + "]")
print("[" + ", ".join(Row3) + "]")
print("[" + ", ".join(Row4) + "]")
print("[" + ", ".join(Row5) + "]")
print("[" + ", ".join(Row6) + "]")

print(f"\n{Player2} your turn.")
Play2 = int(input(f"Which column do you want to drop your {Player2Color} piece into?\n"))

if Row6[Play2] == colored("0", "black"):
    Row6[Play2] = colored("0",f"{Player2Color}")
elif Row5[Play2] == colored("0", "black"):
    Row5[Play2] = colored("0",f"{Player2Color}")
elif Row4[Play2] == colored("0", "black"):
    Row4[Play2] = colored("0",f"{Player2Color}")
elif Row3[Play2] == colored("0", "black"):
    Row3[Play2] = colored("0",f"{Player2Color}")
elif Row2[Play2] == colored("0", "black"):
    Row2[Play2] = colored("0",f"{Player2Color}")
elif Row1[Play2] == colored("0", "black"):
    Row1[Play2] = colored("0",f"{Player2Color}")
else: Play2 = int(input(f"Oop, that is not a valid move.\nWhich column do you want to drop your {Player2Color} piece into?\n"))

print("[" + ", ".join(Row1) + "]")
print("[" + ", ".join(Row2) + "]")
print("[" + ", ".join(Row3) + "]")
print("[" + ", ".join(Row4) + "]")
print("[" + ", ".join(Row5) + "]")
print("[" + ", ".join(Row6) + "]")
